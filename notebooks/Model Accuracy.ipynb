# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df1=pd.read_csv(r'C:\Users\user\Downloads\projectml\projectml\Credit Score Clasificaton\cleaned data\clean.csv')

# %%
df1.to_csv(r"C:\Users\user\Downloads\projectml\projectml\Credit Score Clasificaton\cleaned data\clean.csv",index=False)

# %%
df1
# Out:
#           Month           Name  Age Occupation  Annual_Income  \
# 0       January  Aaron Maashoh   23  Scientist      1911412.0
# 1      February  Aaron Maashoh   23  Scientist      1911412.0
# 2         April  Aaron Maashoh   23  Scientist      1911412.0
# 3           May  Aaron Maashoh   23  Scientist      1911412.0
# 4          June  Aaron Maashoh   23  Scientist      1911412.0
# ...         ...            ...  ...        ...            ...
# 92252     April          Nicks   25   Mechanic      3962899.0
# 92253       May          Nicks   25   Mechanic      3962899.0
# 92254      June          Nicks   25   Mechanic      3962899.0
# 92255      July          Nicks   25   Mechanic      3962899.0
# 92256    August          Nicks   25   Mechanic      3962899.0
#
#        Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  \
# 0                1824.843333                  3                4
# 1                2295.058333                  3                4
# ...

# %%
df1.shape
# Out:
# (92257, 23)

# %%
df1.head()
# Out:
#       Month           Name  Age Occupation  Annual_Income  \
# 0   January  Aaron Maashoh   23  Scientist      1911412.0
# 1  February  Aaron Maashoh   23  Scientist      1911412.0
# 2     April  Aaron Maashoh   23  Scientist      1911412.0
# 3       May  Aaron Maashoh   23  Scientist      1911412.0
# 4      June  Aaron Maashoh   23  Scientist      1911412.0
#
#    Monthly_Inhand_Salary  Num_Bank_Accounts  Num_Credit_Card  Interest_Rate  \
# 0            1824.843333                  3                4              3
# 1            2295.058333                  3                4              3
# 2            2295.058333                  3                4              3
# 3            1824.843333                  3                4              3
# 4            2295.058333                  3                4              3
#
#    Num_of_Loan  ... Num_Credit_Inquiries  Credit_Mix Outstanding_Debt  \
# 0          4.0  ...                  4.0         NaN           809.98
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 92257 entries, 0 to 92256
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Month                     92257 non-null  object
#  1   Name                      92257 non-null  object
#  2   Age                       92257 non-null  int64
#  3   Occupation                92257 non-null  object
#  4   Annual_Income             92257 non-null  float64
#  5   Monthly_Inhand_Salary     92257 non-null  float64
#  6   Num_Bank_Accounts         92257 non-null  int64
#  7   Num_Credit_Card           92257 non-null  int64
#  8   Interest_Rate             92257 non-null  int64
#  9   Num_of_Loan               92257 non-null  float64
#  10  Type_of_Loan              92257 non-null  object
#  11  Delay_from_due_date       92257 non-null  int64
#  12  Changed_Credit_Limit      92257 non-null  object
# ...

# %%
df1.describe()
# Out:
#                 Age  Annual_Income  Monthly_Inhand_Salary  Num_Bank_Accounts  \
# count  92257.000000   9.225700e+04           92257.000000       92257.000000
# mean      33.383451   1.182021e+13            3927.772020          17.051801
# std       10.781187   3.096440e+14            3021.644483         117.599631
# min       14.000000   7.908000e+03             303.645417          -1.000000
# 25%       24.000000   1.824625e+06            1809.564167           3.000000
# 50%       33.000000   3.806068e+06            2635.268333           5.000000
# 75%       42.000000   8.093292e+06            5411.671667           7.000000
# max       67.000000   1.349284e+16           15204.633330        1798.000000
#
#        Num_Credit_Card  Interest_Rate   Num_of_Loan  Delay_from_due_date  \
# count     92257.000000   92257.000000  92257.000000         92257.000000
# mean         22.462957      72.771855     10.680371            20.834658
# ...

# %%
df1.isnull().sum().sum()
# Out:
# 18622

# %%
df1['Credit_Score'].value_counts(normalize=True) * 100
# Out:
# Credit_Score
# Standard    53.462610
# Poor        28.474804
# Good        18.062586
# Name: proportion, dtype: float64

# %%
df1.columns
# Out:
# Index(['Month', 'Name', 'Age', 'Occupation', 'Annual_Income',
#        'Monthly_Inhand_Salary', 'Num_Bank_Accounts', 'Num_Credit_Card',
#        'Interest_Rate', 'Num_of_Loan', 'Type_of_Loan', 'Delay_from_due_date',
#        'Changed_Credit_Limit', 'Num_Credit_Inquiries', 'Credit_Mix',
#        'Outstanding_Debt', 'Credit_Utilization_Ratio', 'Payment_of_Min_Amount',
#        'Total_EMI_per_month', 'Amount_invested_monthly', 'Payment_Behaviour',
#        'Monthly_Balance', 'Credit_Score'],
#       dtype='object')

# %%
fig, ax = plt.subplots(5, 3, figsize=(19, 20))

ax = ax.flatten()

sns.boxplot(x='Credit_Score', y='Annual_Income', data=df1, ax=ax[0])
sns.boxplot(x='Credit_Score', y='Monthly_Inhand_Salary', data=df1, ax=ax[1])
sns.boxplot(x='Credit_Score', y='Num_Bank_Accounts', data=df1, ax=ax[2])
sns.boxplot(x='Credit_Score', y='Num_Credit_Card', data=df1, ax=ax[3])
sns.boxplot(x='Credit_Score', y='Interest_Rate', data=df1, ax=ax[4])
sns.boxplot(x='Credit_Score', y='Num_of_Loan', data=df1, ax=ax[5])
sns.boxplot(x='Credit_Score', y='Delay_from_due_date', data=df1, ax=ax[6])
sns.boxplot(x='Credit_Score', y='Num_Credit_Inquiries', data=df1, ax=ax[7])
sns.boxplot(x='Credit_Score', y='Credit_Utilization_Ratio', data=df1, ax=ax[8])
sns.boxplot(x='Credit_Score', y='Total_EMI_per_month', data=df1, ax=ax[9])
sns.boxplot(x='Credit_Score', y='Amount_invested_monthly', data=df1, ax=ax[10])
sns.boxplot(x='Credit_Score', y='Monthly_Balance', data=df1, ax=ax[11])
sns.boxplot(x='Credit_Score', y='Age', data=df1, ax=ax[12])



fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(11):
    ax[i].grid(color='white', linestyle='-', linewidth=2, alpha=0.5)

    fig.suptitle('Relationship between Credit Score and Different Features', fontsize=16, fontweight='bold')

    titles = ['Annual Income', 'Monthly Inhand Salary', 'Number of Bank Accounts', 'Number of Credit Cards', 
          'Interest Rate', 'Number of Loans', 'Delay from Due Date','Number of Credit Inquiries', 'Credit Utilization Score', 'Total EMI Per Month','Amount Invested Monthly', 'Monthly Balance', 'Age']

    for i in range(5):
        ax[i].set_title(titles[i], fontsize=14, fontweight='bold')


plt.show()

# %%
df1['Credit_Mix'].unique()
# Out:
# array([nan,  2.,  1.,  0.])

# %%
df1['Credit_Mix'] = df1['Credit_Mix'].map({'Good': 2, 'Standard': 1, 'Bad': 0})

# %%
df1['Credit_Mix'].unique()
# Out:
# array([nan])

# %%
from sklearn.model_selection import train_test_split

# %%
X = df1[["Annual_Income", "Monthly_Inhand_Salary", "Num_Bank_Accounts", "Num_Credit_Card", "Interest_Rate", "Num_of_Loan", 
        "Delay_from_due_date","Num_Credit_Inquiries","Credit_Utilization_Ratio" ,"Total_EMI_per_month","Amount_invested_monthly","Age", "Monthly_Balance"]].values
y = df1['Credit_Score'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
X_train
# Out:
# array([[3.33469200e+06, 2.69600250e+03, 5.00000000e+00, ...,
#         1.36974034e+02, 5.20000000e+01, 4.22816966e+02],
#        [2.21599500e+06, 1.73966250e+03, 8.00000000e+00, ...,
#         6.34821237e+01, 4.60000000e+01, 4.00484126e+02],
#        [4.00694500e+06, 2.29505833e+03, 3.00000000e+00, ...,
#         2.02362770e+02, 3.10000000e+01, 3.86184508e+02],
#        ...,
#        [1.26353040e+07, 1.06354200e+04, 4.00000000e+00, ...,
#         5.49766139e+02, 3.10000000e+01, 0.00000000e+00],
#        [2.00052200e+06, 1.68310167e+03, 8.00000000e+00, ...,
#         7.15462556e+01, 4.30000000e+01, 3.07250697e+02],
#        [2.56314800e+06, 2.05895667e+03, 3.00000000e+00, ...,
#         6.36363155e+01, 1.80000000e+01, 3.36584352e+02]])

# %%
y_train
# Out:
# array(['Good', 'Standard', 'Good', ..., 'Poor', 'Poor', 'Standard'],
#       dtype=object)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model = RandomForestClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
print('Classification Report', classification_report(y_test, predictions))
print('\n')
print('Confusion Matrix', confusion_matrix(y_test, predictions))
print('\n')
print('Accuracy Score', accuracy_score(y_test, predictions))
# Out:
# Classification Report               precision    recall  f1-score   support
#
#         Good       0.75      0.68      0.71      3279
#         Poor       0.76      0.78      0.77      5237
#     Standard       0.79      0.81      0.80      9936
#
#     accuracy                           0.78     18452
#    macro avg       0.77      0.75      0.76     18452
# weighted avg       0.78      0.78      0.78     18452
#
#
#
# Confusion Matrix [[2222   23 1034]
#  [  58 4087 1092]
#  [ 687 1235 8014]]
#
#
# Accuracy Score 0.7762302189464557

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = model.predict(X_test)

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
print('Classification Report', classification_report(y_test, predictions))
print('\n')
print('Confusion Matrix', confusion_matrix(y_test, predictions))
print('\n')
print('Accuracy Score', accuracy_score(y_test, predictions))
# Out:
# Classification Report               precision    recall  f1-score   support
#
#         Good       0.62      0.61      0.62      3279
#         Poor       0.68      0.68      0.68      5237
#     Standard       0.73      0.73      0.73      9936
#
#     accuracy                           0.70     18452
#    macro avg       0.68      0.68      0.68     18452
# weighted avg       0.70      0.70      0.70     18452
#
#
#
# Confusion Matrix [[2005  143 1131]
#  [ 120 3575 1542]
#  [1096 1549 7291]]
#
#
# Accuracy Score 0.6975395621070887

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
print('Classification Report', classification_report(y_test, predictions))
print('\n')
print('Confusion Matrix', confusion_matrix(y_test, predictions))
print('\n')
print('Accuracy Score', accuracy_score(y_test, predictions))
# Out:
# Classification Report               precision    recall  f1-score   support
#
#         Good       0.62      0.61      0.62      3279
#         Poor       0.68      0.68      0.68      5237
#     Standard       0.73      0.73      0.73      9936
#
#     accuracy                           0.70     18452
#    macro avg       0.68      0.68      0.68     18452
# weighted avg       0.70      0.70      0.70     18452
#
#
#
# Confusion Matrix [[2005  143 1131]
#  [ 120 3575 1542]
#  [1096 1549 7291]]
#
#
# Accuracy Score 0.6975395621070887

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model = GaussianNB()

# %%
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
print('Classification Report', classification_report(y_test, predictions))
print('\n')
print('Confusion Matrix', confusion_matrix(y_test, predictions))
print('\n')
print('Accuracy Score', accuracy_score(y_test, predictions))
# Out:
# Classification Report               precision    recall  f1-score   support
#
#         Good       0.62      0.61      0.62      3279
#         Poor       0.68      0.68      0.68      5237
#     Standard       0.73      0.73      0.73      9936
#
#     accuracy                           0.70     18452
#    macro avg       0.68      0.68      0.68     18452
# weighted avg       0.70      0.70      0.70     18452
#
#
#
# Confusion Matrix [[2005  143 1131]
#  [ 120 3575 1542]
#  [1096 1549 7291]]
#
#
# Accuracy Score 0.6975395621070887

# %%
from sklearn.model_selection import RandomizedSearchCV
import pandas as pd 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import r2_score 
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=0)

# %%
model = LogisticRegression()

# %%
param_space = {'penalty': ['l2'], 
               'n_jobs': [None], 
               "C":[1.0],
               'l1_ratio': [None],
               'verbose': [0],
               "solver":['lbfgs'],
               "class_weight":[None]}

# %%
random_search = RandomizedSearchCV(model, param_space, n_iter=100, cv=5)
random_search.fit(X_train, y_train)
# Out:
# c:\Users\user\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:305: UserWarning: The total space of parameters 1 is smaller than n_iter=100. Running 1 iterations. For exhaustive searches, use GridSearchCV.
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=LogisticRegression(), n_iter=100,
#                    param_distributions={'C': [1.0], 'class_weight': [None],
#                                         'l1_ratio': [None], 'n_jobs': [None],
#                                         'penalty': ['l2'], 'solver': ['lbfgs'],
#                                         'verbose': [0]})

# %%
print('Classification Report', classification_report(y_test, predictions))
print('\n')
print('Confusion Matrix', confusion_matrix(y_test, predictions))
print('\n')
print('Accuracy Score', accuracy_score(y_test, predictions))
# Out:
# Classification Report               precision    recall  f1-score   support
#
#         Good       0.62      0.61      0.62      3279
#         Poor       0.68      0.68      0.68      5237
#     Standard       0.73      0.73      0.73      9936
#
#     accuracy                           0.70     18452
#    macro avg       0.68      0.68      0.68     18452
# weighted avg       0.70      0.70      0.70     18452
#
#
#
# Confusion Matrix [[2005  143 1131]
#  [ 120 3575 1542]
#  [1096 1549 7291]]
#
#
# Accuracy Score 0.6975395621070887
